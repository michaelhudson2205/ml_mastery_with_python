# %%
# load required libraries
import numpy as np
import pandas as pd
from scipy.stats import uniform
from sklearn.linear_model import RidgeClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
# load the diabetes dataset
filename = "data/pima-indians-diabetes.data.csv"
names = ["preg", "plas", "pres", "skin", "test", "mass", "pedi", "age", "class"]
data = pd.read_csv(filename, names=names)
array = data.values
X = array[:, 0:8]
y = array[:, 8]

# %%
# Grid search for optimal hyperparameters
alphas = np.array([1, 0.1, 0.01, 0.001, 0.0001, 0])
param_grid = dict(alpha=alphas)
model = RidgeClassifier()
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=3)
grid_result = grid.fit(X, y)
# summarize results
print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")
# Out:
# Best: 0.7708333333333334 using {'alpha': np.float64(1.0)}

# %%
# Randomized search for optimal hyperparameters
param_grid = {"alpha": uniform()}
model = RidgeClassifier()
rsearch = RandomizedSearchCV(
    estimator=model, param_distributions=param_grid, n_iter=100, cv=3, random_state=7
)
rsearch_result = rsearch.fit(X, y)
# summarize results
print(f"Best: {rsearch_result.best_score_} using {rsearch_result.best_params_}")
# Out:
# Best: 0.7708333333333334 using {'alpha': np.float64(0.07630828937395717)}
